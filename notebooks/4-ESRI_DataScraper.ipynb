# %% [markdown]
# ## ESRI Data Scraper
# Pulls features from ESRI Map Servers

# %%
import requests,json

# %%
serviceURL = 'http://gisweb2.ci.durham.nc.us/arcgis/rest/services/SecuredMaps/NaturalHeritageAreas/MapServer'

# %%
requests.get(serviceURL+"p=pjson")
# Out:
# <Response [400]>
